# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path = "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Fortis_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Fortis', size=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path = "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Glenmark_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Glenmark', size=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path = "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Lal_path_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Dr. Lal Path Labs', size=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path = "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Metropolis_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Metropolis', size=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path =  "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Star_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Star Health', size=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the path to text file
file_path = "C:\\Users\\rohit\\OneDrive\\Desktop\\BFM\\RHP\\Thyrocare_rhp.txt"

# Read the text file
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Define a function to preprocess the text 
def preprocess_text_advanced(text):
    # Convert text to lowercase
    text = text.lower()
    
    # Remove punctuation
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Tokenize the text
    words = word_tokenize(text)
    
    # Apply lemmatization 
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    return ' '.join(words)

# Preprocess the text data using the advanced preprocessing function
preprocessed_text_advanced = preprocess_text_advanced(text)

# Combine the preprocessed text data into one string
combined_text_data = preprocessed_text_advanced

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Calculate the TF-IDF values for the words in the text
tfidf_matrix = tfidf_vectorizer.fit_transform([combined_text_data])

# Get the feature names (words) from the TF-IDF vectorizer
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a dense array
dense_array = tfidf_matrix.toarray()

# Create a dictionary with words as keys and TF-IDF values as values
word_tfidf_dict = dict(zip(feature_names, dense_array[0]))

# Define the path to the font file 
font_path = 'C:/Windows/Fonts/FORTE'

# Create a WordCloud object with customized word sizes based on TF-IDF values
wordcloud = WordCloud(
    width=1000,
    height=500,
    max_font_size=50,
    background_color='black',
    font_path=font_path,
    prefer_horizontal=0.7  # You can adjust this parameter to control word orientation
)

# Generate the WordCloud with TF-IDF weighted words
wordcloud.generate_from_frequencies(word_tfidf_dict)

# Display the WordCloud 
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Thyrocare', size=20)
plt.axis('off')
plt.show()
